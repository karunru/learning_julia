# %%
using Flux

# %%
srand(1)
# Out:
# MersenneTwister(UInt32[0x00000001], Base.dSFMT.DSFMT_state(Int32[1749029653, 1072851681, 1610647787, 1072862326, 1841712345, 1073426746, -198061126, 1073322060, -156153802, 1073567984  …  1977574422, 1073209915, 278919868, 1072835605, 1290372147, 18858467, 1815133874, -1716870370, 382, 0]), [1.73972, 1.43373, 1.64774, 1.1389, 1.82812, 1.23344, 1.7453, 1.65896, 1.88859, 1.9765  …  1.00845, 1.03748, 1.70504, 1.99904, 1.29435, 1.45734, 1.14048, 1.07644, 1.17095, 1.68617], 382)

# %%
n = 10
# Out:
# 10

# %%
k = 4
# Out:
# 4

# %%
w₀ = rand()
# Out:
# 0.23603334566204692

# %%
w = rand(n)
# Out:
# 10-element Array{Float64,1}:
#  0.346517
#  0.312707
#  0.00790928
#  0.488613
#  0.210968
#  0.951916
#  0.999905
#  0.251662
#  0.986666
#  0.555751

# %%
v = rand(n, k)
# Out:
# 10×4 Array{Float64,2}:
#  0.437108   0.640396   0.185821   0.894166
#  0.424718   0.873544   0.111981   0.648054
#  0.773223   0.278582   0.976312   0.417039
#  0.28119    0.751313   0.0516146  0.144566
#  0.209472   0.644883   0.53803    0.622403
#  0.251379   0.0778264  0.455692   0.872334
#  0.0203749  0.848185   0.279395   0.524975
#  0.287702   0.0856352  0.178246   0.241591
#  0.859512   0.553206   0.548983   0.884837
#  0.0769509  0.46335    0.370971   0.440897

# %%
function predict(x)
    tmp = 0
    tmp_dot = 0
    for f in 1:k
        tmp_a = 0
        tmp_b = 0
        for i in 1:n
            tmp_a += v[i, f] .* x[i]
            tmp_b += (v[i, f].^2) .* (x[i].^2)
        end
        tmp += (tmp_a.^2) - tmp_b
        tmp_dot += w[f] .* x[f]
    end
    return w₀ .+ tmp_dot .+ 0.5.*tmp
end
# Out:
# predict (generic function with 1 method)

# %%
loss(x, y) = @show(Flux.mse(predict(x), y))
# Out:
# loss (generic function with 1 method)

# %%
x, y = rand(n), rand()
# Out:
# ([0.404673, 0.736787, 0.953803, 0.0951856, 0.519675, 0.0135403, 0.303399, 0.702557, 0.596537, 0.638935], 0.8723474485143243)

# %%
l = loss(x, y)
# Out:
# Flux.mse(predict(x), y) = 85.0868581409456

# %%
w₀ = param(w₀)
w = param(w)
v = param(v)
# Out:
# Tracked 10×4 Array{Float64,2}:
#  0.437108   0.640396   0.185821   0.894166
#  0.424718   0.873544   0.111981   0.648054
#  0.773223   0.278582   0.976312   0.417039
#  0.28119    0.751313   0.0516146  0.144566
#  0.209472   0.644883   0.53803    0.622403
#  0.251379   0.0778264  0.455692   0.872334
#  0.0203749  0.848185   0.279395   0.524975
#  0.287702   0.0856352  0.178246   0.241591
#  0.859512   0.553206   0.548983   0.884837
#  0.0769509  0.46335    0.370971   0.440897

# %%
opt = ADAM([w₀, w, v])
# Out:
# (::#71) (generic function with 1 method)

# %%
opt()

# %%
data = [(x,y)]
# Out:
# 1-element Array{Tuple{Array{Float64,1},Float64},1}:
#  ([0.404673, 0.736787, 0.953803, 0.0951856, 0.519675, 0.0135403, 0.303399, 0.702557, 0.596537, 0.638935], 0.872347)

# %%
Flux.train!(loss, data, opt)
# Out:
# Flux.mse(predict(x), y) = param(85.0869)

# %%
v
# Out:
# Tracked 10×4 Array{Float64,2}:
#  0.436364   0.639652   0.185077   0.893422
#  0.423974   0.8728     0.111237   0.64731
#  0.772479   0.277838   0.975568   0.416295
#  0.280446   0.750568   0.0508705  0.143821
#  0.208728   0.644139   0.537285   0.621659
#  0.250635   0.0770823  0.454948   0.87159
#  0.0196307  0.847441   0.278651   0.524231
#  0.286957   0.084891   0.177502   0.240846
#  0.858768   0.552461   0.548239   0.884093
#  0.0762068  0.462606   0.370227   0.440153

# %%
l = loss(x, y)
# Out:
# Flux.mse(predict(x), y) = param(84.482)
# Tracked 0-dimensional Array{Float64,0}:
# 84.482

# %%
x
# Out:
# 10-element Array{Float64,1}:
#  0.404673
#  0.736787
#  0.953803
#  0.0951856
#  0.519675
#  0.0135403
#  0.303399
#  0.702557
#  0.596537
#  0.638935

# %%
y
# Out:
# 0.8723474485143243

# %%
predict(x) - y
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# 9.19141

# %%
Flux.train!(loss, data, opt)
# Out:
# Flux.mse(predict(x), y) = param(84.482)

# %%
predict(x) - y
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# 9.15358

# %%
while l > 0.0001
    Flux.train!(loss, data, opt)
    l = loss(x, y)
end
# Out:
# Flux.mse(predict(x), y) = param(83.788)
# Flux.mse(predict(x), y) = param(83.0572)
# Flux.mse(predict(x), y) = param(83.0572)
# Flux.mse(predict(x), y) = param(82.3081)
# Flux.mse(predict(x), y) = param(82.3081)
# Flux.mse(predict(x), y) = param(81.5495)
# Flux.mse(predict(x), y) = param(81.5495)
# Flux.mse(predict(x), y) = param(80.7863)
# Flux.mse(predict(x), y) = param(80.7863)
# Flux.mse(predict(x), y) = param(80.0216)
# Flux.mse(predict(x), y) = param(80.0216)
# Flux.mse(predict(x), y) = param(79.2573)
# Flux.mse(predict(x), y) = param(79.2573)
# Flux.mse(predict(x), y) = param(78.4949)
# Flux.mse(predict(x), y) = param(78.4949)
# Flux.mse(predict(x), y) = param(77.7353)
# Flux.mse(predict(x), y) = param(77.7353)
# Flux.mse(predict(x), y) = param(76.9793)
# Flux.mse(predict(x), y) = param(76.9793)
# Flux.mse(predict(x), y) = param(76.2275)
# Flux.mse(predict(x), y) = param(76.2275)
# Flux.mse(predict(x), y) = param(75.4804)
# Flux.mse(predict(x), y) = param(75.4804)
# Flux.mse(predict(x), y) = param(74.7383)
# Flux.mse(predict(x), y) = param(74.7383)
# Flux.mse(predict(x), y) = param(74.0015)
# Flux.mse(predict(x), y) = param(74.0015)
# Flux.mse(predict(x), y) = param(73.2703)
# Flux.mse(predict(x), y) = param(73.2703)
# Flux.mse(predict(x), y) = param(72.5448)
# Flux.mse(predict(x), y) = param(72.5448)
# Flux.mse(predict(x), y) = param(71.8252)
# Flux.mse(predict(x), y) = param(71.8252)
# Flux.mse(predict(x), y) = param(71.1117)
# Flux.mse(predict(x), y) = param(71.1117)
# Flux.mse(predict(x), y) = param(70.4043)
# Flux.mse(predict(x), y) = param(70.4043)
# Flux.mse(predict(x), y) = param(69.7031)
# Flux.mse(predict(x), y) = param(69.7031)
# Flux.mse(predict(x), y) = param(69.0082)
# Flux.mse(predict(x), y) = param(69.0082)
# Flux.mse(predict(x), y) = param(68.3197)
# Flux.mse(predict(x), y) = param(68.3197)
# Flux.mse(predict(x), y) = param(67.6375)
# Flux.mse(predict(x), y) = param(67.6375)
# Flux.mse(predict(x), y) = param(66.9618)
# Flux.mse(predict(x), y) = param(66.9618)
# Flux.mse(predict(x), y) = param(66.2925)
# Flux.mse(predict(x), y) = param(66.2925)
# Flux.mse(predict(x), y) = param(65.6297)
# Flux.mse(predict(x), y) = param(65.6297)
# Flux.mse(predict(x), y) = param(64.9734)
# Flux.mse(predict(x), y) = param(64.9734)
# Flux.mse(predict(x), y) = param(64.3234)
# Flux.mse(predict(x), y) = param(64.3234)
# Flux.mse(predict(x), y) = param(63.68)
# Flux.mse(predict(x), y) = param(63.68)
# Flux.mse(predict(x), y) = param(63.0429)
# Flux.mse(predict(x), y) = param(63.0429)
# Flux.mse(predict(x), y) = param(62.4123)
# Flux.mse(predict(x), y) = param(62.4123)
# Flux.mse(predict(x), y) = param(61.788)
# Flux.mse(predict(x), y) = param(61.788)
# Flux.mse(predict(x), y) = param(61.1701)
# Flux.mse(predict(x), y) = param(61.1701)
# Flux.mse(predict(x), y) = param(60.5585)
# Flux.mse(predict(x), y) = param(60.5585)
# Flux.mse(predict(x), y) = param(59.9532)
# Flux.mse(predict(x), y) = param(59.9532)
# Flux.mse(predict(x), y) = param(59.3542)
# Flux.mse(predict(x), y) = param(59.3542)
# Flux.mse(predict(x), y) = param(58.7613)
# Flux.mse(predict(x), y) = param(58.7613)
# Flux.mse(predict(x), y) = param(58.1747)
# Flux.mse(predict(x), y) = param(58.1747)
# Flux.mse(predict(x), y) = param(57.5941)
# Flux.mse(predict(x), y) = param(57.5941)
# Flux.mse(predict(x), y) = param(57.0196)
# Flux.mse(predict(x), y) = param(57.0196)
# Flux.mse(predict(x), y) = param(56.4511)
# Flux.mse(predict(x), y) = param(56.4511)
# Flux.mse(predict(x), y) = param(55.8886)
# Flux.mse(predict(x), y) = param(55.8886)
# Flux.mse(predict(x), y) = param(55.332)
# Flux.mse(predict(x), y) = param(55.332)
# Flux.mse(predict(x), y) = param(54.7813)
# Flux.mse(predict(x), y) = param(54.7813)
# Flux.mse(predict(x), y) = param(54.2364)
# Flux.mse(predict(x), y) = param(54.2364)
# Flux.mse(predict(x), y) = param(53.6972)
# Flux.mse(predict(x), y) = param(53.6972)
# Flux.mse(predict(x), y) = param(53.1638)
# Flux.mse(predict(x), y) = param(53.1638)
# Flux.mse(predict(x), y) = param(52.636)
# Flux.mse(predict(x), y) = param(52.636)
# Flux.mse(predict(x), y) = param(52.1138)
# Flux.mse(predict(x), y) = param(52.1138)
# Flux.mse(predict(x), y) = param(51.5971)
# Flux.mse(predict(x), y) = param(51.5971)
# Flux.mse(predict(x), y) = param(51.0859)
# Flux.mse(predict(x), y) = param(51.0859)
# Flux.mse(predict(x), y) = param(50.5802)
# Flux.mse(predict(x), y) = param(50.5802)
# Flux.mse(predict(x), y) = param(50.0798)
# Flux.mse(predict(x), y) = param(50.0798)
# Flux.mse(predict(x), y) = param(49.5847)
# Flux.mse(predict(x), y) = param(49.5847)
# Flux.mse(predict(x), y) = param(49.0949)
# Flux.mse(predict(x), y) = param(49.0949)
# Flux.mse(predict(x), y) = param(48.6103)
# Flux.mse(predict(x), y) = param(48.6103)
# Flux.mse(predict(x), y) = param(48.1309)
# Flux.mse(predict(x), y) = param(48.1309)
# Flux.mse(predict(x), y) = param(47.6565)
# Flux.mse(predict(x), y) = param(47.6565)
# Flux.mse(predict(x), y) = param(47.1872)
# Flux.mse(predict(x), y) = param(47.1872)
# Flux.mse(predict(x), y) = param(46.7229)
# Flux.mse(predict(x), y) = param(46.7229)
# Flux.mse(predict(x), y) = param(46.2635)
# Flux.mse(predict(x), y) = param(46.2635)
# Flux.mse(predict(x), y) = param(45.8089)
# Flux.mse(predict(x), y) = param(45.8089)
# Flux.mse(predict(x), y) = param(45.3592)
# Flux.mse(predict(x), y) = param(45.3592)
# Flux.mse(predict(x), y) = param(44.9142)
# Flux.mse(predict(x), y) = param(44.9142)
# Flux.mse(predict(x), y) = param(44.474)
# Flux.mse(predict(x), y) = param(44.474)
# Flux.mse(predict(x), y) = param(44.0384)
# Flux.mse(predict(x), y) = param(44.0384)
# Flux.mse(predict(x), y) = param(43.6075)
# Flux.mse(predict(x), y) = param(43.6075)
# Flux.mse(predict(x), y) = param(43.181)
# Flux.mse(predict(x), y) = param(43.181)
# Flux.mse(predict(x), y) = param(42.7591)
# Flux.mse(predict(x), y) = param(42.7591)
# Flux.mse(predict(x), y) = param(42.3417)
# Flux.mse(predict(x), y) = param(42.3417)
# Flux.mse(predict(x), y) = param(41.9286)
# Flux.mse(predict(x), y) = param(41.9286)
# Flux.mse(predict(x), y) = param(41.5199)
# Flux.mse(predict(x), y) = param(41.5199)
# Flux.mse(predict(x), y) = param(41.1156)
# Flux.mse(predict(x), y) = param(41.1156)
# Flux.mse(predict(x), y) = param(40.7154)
# Flux.mse(predict(x), y) = param(40.7154)
# Flux.mse(predict(x), y) = param(40.3195)
# Flux.mse(predict(x), y) = param(40.3195)
# Flux.mse(predict(x), y) = param(39.9278)
# Flux.mse(predict(x), y) = param(39.9278)
# Flux.mse(predict(x), y) = param(39.5401)
# Flux.mse(predict(x), y) = param(39.5401)
# Flux.mse(predict(x), y) = param(39.1565)
# Flux.mse(predict(x), y) = param(39.1565)
# Flux.mse(predict(x), y) = param(38.777)
# Flux.mse(predict(x), y) = param(38.777)
# Flux.mse(predict(x), y) = param(38.4014)
# Flux.mse(predict(x), y) = param(38.4014)
# Flux.mse(predict(x), y) = param(38.0298)
# Flux.mse(predict(x), y) = param(38.0298)
# Flux.mse(predict(x), y) = param(37.662)
# Flux.mse(predict(x), y) = param(37.662)
# Flux.mse(predict(x), y) = param(37.2981)
# Flux.mse(predict(x), y) = param(37.2981)
# Flux.mse(predict(x), y) = param(36.938)
# Flux.mse(predict(x), y) = param(36.938)
# Flux.mse(predict(x), y) = param(36.5817)
# Flux.mse(predict(x), y) = param(36.5817)
# Flux.mse(predict(x), y) = param(36.229)
# Flux.mse(predict(x), y) = param(36.229)
# Flux.mse(predict(x), y) = param(35.8801)
# Flux.mse(predict(x), y) = param(35.8801)
# Flux.mse(predict(x), y) = param(35.5347)
# Flux.mse(predict(x), y) = param(35.5347)
# Flux.mse(predict(x), y) = param(35.193)
# Flux.mse(predict(x), y) = param(35.193)
# Flux.mse(predict(x), y) = param(34.8548)
# Flux.mse(predict(x), y) = param(34.8548)
# Flux.mse(predict(x), y) = param(34.5201)
# Flux.mse(predict(x), y) = param(34.5201)
# Flux.mse(predict(x), y) = param(34.1889)
# Flux.mse(predict(x), y) = param(34.1889)
# Flux.mse(predict(x), y) = param(33.8611)
# Flux.mse(predict(x), y) = param(33.8611)
# Flux.mse(predict(x), y) = param(33.5367)
# Flux.mse(predict(x), y) = param(33.5367)
# Flux.mse(predict(x), y) = param(33.2157)
# Flux.mse(predict(x), y) = param(33.2157)
# Flux.mse(predict(x), y) = param(32.898)
# Flux.mse(predict(x), y) = param(32.898)
# Flux.mse(predict(x), y) = param(32.5836)
# Flux.mse(predict(x), y) = param(32.5836)
# Flux.mse(predict(x), y) = param(32.2724)
# Flux.mse(predict(x), y) = param(32.2724)
# Flux.mse(predict(x), y) = param(31.9644)
# Flux.mse(predict(x), y) = param(31.9644)
# Flux.mse(predict(x), y) = param(31.6596)
# Flux.mse(predict(x), y) = param(31.6596)
# Flux.mse(predict(x), y) = param(31.3579)
# Flux.mse(predict(x), y) = param(31.3579)
# Flux.mse(predict(x), y) = param(31.0593)
# Flux.mse(predict(x), y) = param(31.0593)
# Flux.mse(predict(x), y) = param(30.7638)
# Flux.mse(predict(x), y) = param(30.7638)
# Flux.mse(predict(x), y) = param(30.4713)
# Flux.mse(predict(x), y) = param(30.4713)
# Flux.mse(predict(x), y) = param(30.1818)
# Flux.mse(predict(x), y) = param(30.1818)
# Flux.mse(predict(x), y) = param(29.8953)
# Flux.mse(predict(x), y) = param(29.8953)
# Flux.mse(predict(x), y) = param(29.6117)
# Flux.mse(predict(x), y) = param(29.6117)
# Flux.mse(predict(x), y) = param(29.331)
# Flux.mse(predict(x), y) = param(29.331)
# Flux.mse(predict(x), y) = param(29.0532)
# Flux.mse(predict(x), y) = param(29.0532)
# Flux.mse(predict(x), y) = param(28.7782)
# Flux.mse(predict(x), y) = param(28.7782)
# Flux.mse(predict(x), y) = param(28.5061)
# Flux.mse(predict(x), y) = param(28.5061)
# Flux.mse(predict(x), y) = param(28.2367)
# Flux.mse(predict(x), y) = param(28.2367)
# Flux.mse(predict(x), y) = param(27.97)
# Flux.mse(predict(x), y) = param(27.97)
# Flux.mse(predict(x), y) = param(27.706)
# Flux.mse(predict(x), y) = param(27.706)
# Flux.mse(predict(x), y) = param(27.4448)
# Flux.mse(predict(x), y) = param(27.4448)
# Flux.mse(predict(x), y) = param(27.1861)
# Flux.mse(predict(x), y) = param(27.1861)
# Flux.mse(predict(x), y) = param(26.9301)
# Flux.mse(predict(x), y) = param(26.9301)
# Flux.mse(predict(x), y) = param(26.6767)
# Flux.mse(predict(x), y) = param(26.6767)
# Flux.mse(predict(x), y) = param(26.4259)
# Flux.mse(predict(x), y) = param(26.4259)
# Flux.mse(predict(x), y) = param(26.1776)
# Flux.mse(predict(x), y) = param(26.1776)
# Flux.mse(predict(x), y) = param(25.9318)
# Flux.mse(predict(x), y) = param(25.9318)
# Flux.mse(predict(x), y) = param(25.6885)
# Flux.mse(predict(x), y) = param(25.6885)
# Flux.mse(predict(x), y) = param(25.4477)
# Flux.mse(predict(x), y) = param(25.4477)
# Flux.mse(predict(x), y) = param(25.2092)
# Flux.mse(predict(x), y) = param(25.2092)
# Flux.mse(predict(x), y) = param(24.9732)
# Flux.mse(predict(x), y) = param(24.9732)
# Flux.mse(predict(x), y) = param(24.7396)
# Flux.mse(predict(x), y) = param(24.7396)
# Flux.mse(predict(x), y) = param(24.5083)
# Flux.mse(predict(x), y) = param(24.5083)
# Flux.mse(predict(x), y) = param(24.2793)
# Flux.mse(predict(x), y) = param(24.2793)
# Flux.mse(predict(x), y) = param(24.0526)
# Flux.mse(predict(x), y) = param(24.0526)
# Flux.mse(predict(x), y) = param(23.8282)
# Flux.mse(predict(x), y) = param(23.8282)
# Flux.mse(predict(x), y) = param(23.606)
# Flux.mse(predict(x), y) = param(23.606)
# Flux.mse(predict(x), y) = param(23.3861)
# Flux.mse(predict(x), y) = param(23.3861)
# Flux.mse(predict(x), y) = param(23.1684)
# Flux.mse(predict(x), y) = param(23.1684)
# Flux.mse(predict(x), y) = param(22.9528)
# Flux.mse(predict(x), y) = param(22.9528)
# Flux.mse(predict(x), y) = param(22.7394)
# Flux.mse(predict(x), y) = param(22.7394)
# Flux.mse(predict(x), y) = param(22.5281)
# Flux.mse(predict(x), y) = param(22.5281)
# Flux.mse(predict(x), y) = param(22.319)
# Flux.mse(predict(x), y) = param(22.319)
# Flux.mse(predict(x), y) = param(22.1119)
# Flux.mse(predict(x), y) = param(22.1119)
# Flux.mse(predict(x), y) = param(21.9069)
# Flux.mse(predict(x), y) = param(21.9069)
# Flux.mse(predict(x), y) = param(21.7039)
# Flux.mse(predict(x), y) = param(21.7039)
# Flux.mse(predict(x), y) = param(21.5029)
# Flux.mse(predict(x), y) = param(21.5029)
# Flux.mse(predict(x), y) = param(21.3039)
# Flux.mse(predict(x), y) = param(21.3039)
# Flux.mse(predict(x), y) = param(21.1069)
# Flux.mse(predict(x), y) = param(21.1069)
# Flux.mse(predict(x), y) = param(20.9119)
# Flux.mse(predict(x), y) = param(20.9119)
# Flux.mse(predict(x), y) = param(20.7187)
# Flux.mse(predict(x), y) = param(20.7187)
# Flux.mse(predict(x), y) = param(20.5275)
# Flux.mse(predict(x), y) = param(20.5275)
# Flux.mse(predict(x), y) = param(20.3382)
# Flux.mse(predict(x), y) = param(20.3382)
# Flux.mse(predict(x), y) = param(20.1508)
# Flux.mse(predict(x), y) = param(20.1508)
# Flux.mse(predict(x), y) = param(19.9652)
# Flux.mse(predict(x), y) = param(19.9652)
# Flux.mse(predict(x), y) = param(19.7814)
# Flux.mse(predict(x), y) = param(19.7814)
# Flux.mse(predict(x), y) = param(19.5994)
# Flux.mse(predict(x), y) = param(19.5994)
# Flux.mse(predict(x), y) = param(19.4193)
# Flux.mse(predict(x), y) = param(19.4193)
# Flux.mse(predict(x), y) = param(19.2409)
# Flux.mse(predict(x), y) = param(19.2409)
# Flux.mse(predict(x), y) = param(19.0642)
# Flux.mse(predict(x), y) = param(19.0642)
# Flux.mse(predict(x), y) = param(18.8893)
# Flux.mse(predict(x), y) = param(18.8893)
# Flux.mse(predict(x), y) = param(18.7161)
# Flux.mse(predict(x), y) = param(18.7161)
# Flux.mse(predict(x), y) = param(18.5446)
# Flux.mse(predict(x), y) = param(18.5446)
# Flux.mse(predict(x), y) = param(18.3748)
# Flux.mse(predict(x), y) = param(18.3748)
# Flux.mse(predict(x), y) = param(18.2067)
# Flux.mse(predict(x), y) = param(18.2067)
# Flux.mse(predict(x), y) = param(18.0401)
# Flux.mse(predict(x), y) = param(18.0401)
# Flux.mse(predict(x), y) = param(17.8753)
# Flux.mse(predict(x), y) = param(17.8753)
# Flux.mse(predict(x), y) = param(17.712)
# Flux.mse(predict(x), y) = param(17.712)
# Flux.mse(predict(x), y) = param(17.5503)
# Flux.mse(predict(x), y) = param(17.5503)
# Flux.mse(predict(x), y) = param(17.3902)
# Flux.mse(predict(x), y) = param(17.3902)
# Flux.mse(predict(x), y) = param(17.2316)
# Flux.mse(predict(x), y) = param(17.2316)
# Flux.mse(predict(x), y) = param(17.0746)
# Flux.mse(predict(x), y) = param(17.0746)
# Flux.mse(predict(x), y) = param(16.9191)
# Flux.mse(predict(x), y) = param(16.9191)
# Flux.mse(predict(x), y) = param(16.7652)
# Flux.mse(predict(x), y) = param(16.7652)
# Flux.mse(predict(x), y) = param(16.6127)
# Flux.mse(predict(x), y) = param(16.6127)
# Flux.mse(predict(x), y) = param(16.4617)
# Flux.mse(predict(x), y) = param(16.4617)
# Flux.mse(predict(x), y) = param(16.3122)
# Flux.mse(predict(x), y) = param(16.3122)
# Flux.mse(predict(x), y) = param(16.1641)
# Flux.mse(predict(x), y) = param(16.1641)
# Flux.mse(predict(x), y) = param(16.0174)
# Flux.mse(predict(x), y) = param(16.0174)
# Flux.mse(predict(x), y) = param(15.8722)
# Flux.mse(predict(x), y) = param(15.8722)
# Flux.mse(predict(x), y) = param(15.7283)
# Flux.mse(predict(x), y) = param(15.7283)
# Flux.mse(predict(x), y) = param(15.5859)
# Flux.mse(predict(x), y) = param(15.5859)
# Flux.mse(predict(x), y) = param(15.4448)
# Flux.mse(predict(x), y) = param(15.4448)
# Flux.mse(predict(x), y) = param(15.3051)
# Flux.mse(predict(x), y) = param(15.3051)
# Flux.mse(predict(x), y) = param(15.1667)
# Flux.mse(predict(x), y) = param(15.1667)
# Flux.mse(predict(x), y) = param(15.0297)
# Flux.mse(predict(x), y) = param(15.0297)
# Flux.mse(predict(x), y) = param(14.894)
# Flux.mse(predict(x), y) = param(14.894)
# Flux.mse(predict(x), y) = param(14.7595)
# Flux.mse(predict(x), y) = param(14.7595)
# Flux.mse(predict(x), y) = param(14.6264)
# Flux.mse(predict(x), y) = param(14.6264)
# Flux.mse(predict(x), y) = param(14.4946)
# Flux.mse(predict(x), y) = param(14.4946)
# Flux.mse(predict(x), y) = param(14.364)
# Flux.mse(predict(x), y) = param(14.364)
# Flux.mse(predict(x), y) = param(14.2346)
# Flux.mse(predict(x), y) = param(14.2346)
# Flux.mse(predict(x), y) = param(14.1065)
# Flux.mse(predict(x), y) = param(14.1065)
# Flux.mse(predict(x), y) = param(13.9796)
# Flux.mse(predict(x), y) = param(13.9796)
# Flux.mse(predict(x), y) = param(13.854)
# Flux.mse(predict(x), y) = param(13.854)
# Flux.mse(predict(x), y) = param(13.7295)
# Flux.mse(predict(x), y) = param(13.7295)
# Flux.mse(predict(x), y) = param(13.6062)
# Flux.mse(predict(x), y) = param(13.6062)
# Flux.mse(predict(x), y) = param(13.4841)
# Flux.mse(predict(x), y) = param(13.4841)
# Flux.mse(predict(x), y) = param(13.3631)
# Flux.mse(predict(x), y) = param(13.3631)
# Flux.mse(predict(x), y) = param(13.2434)
# Flux.mse(predict(x), y) = param(13.2434)
# Flux.mse(predict(x), y) = param(13.1247)
# Flux.mse(predict(x), y) = param(13.1247)
# Flux.mse(predict(x), y) = param(13.0072)
# Flux.mse(predict(x), y) = param(13.0072)
# Flux.mse(predict(x), y) = param(12.8907)
# Flux.mse(predict(x), y) = param(12.8907)
# Flux.mse(predict(x), y) = param(12.7754)
# Flux.mse(predict(x), y) = param(12.7754)
# Flux.mse(predict(x), y) = param(12.6612)
# Flux.mse(predict(x), y) = param(12.6612)
# Flux.mse(predict(x), y) = param(12.5481)
# Flux.mse(predict(x), y) = param(12.5481)
# Flux.mse(predict(x), y) = param(12.436)
# Flux.mse(predict(x), y) = param(12.436)
# Flux.mse(predict(x), y) = param(12.325)
# Flux.mse(predict(x), y) = param(12.325)
# Flux.mse(predict(x), y) = param(12.215)
# Flux.mse(predict(x), y) = param(12.215)
# Flux.mse(predict(x), y) = param(12.1061)
# Flux.mse(predict(x), y) = param(12.1061)
# Flux.mse(predict(x), y) = param(11.9982)
# Flux.mse(predict(x), y) = param(11.9982)
# Flux.mse(predict(x), y) = param(11.8913)
# Flux.mse(predict(x), y) = param(11.8913)
# Flux.mse(predict(x), y) = param(11.7855)
# Flux.mse(predict(x), y) = param(11.7855)
# Flux.mse(predict(x), y) = param(11.6806)
# Flux.mse(predict(x), y) = param(11.6806)
# Flux.mse(predict(x), y) = param(11.5767)
# Flux.mse(predict(x), y) = param(11.5767)
# Flux.mse(predict(x), y) = param(11.4738)
# Flux.mse(predict(x), y) = param(11.4738)
# Flux.mse(predict(x), y) = param(11.3718)
# Flux.mse(predict(x), y) = param(11.3718)
# Flux.mse(predict(x), y) = param(11.2708)
# Flux.mse(predict(x), y) = param(11.2708)
# Flux.mse(predict(x), y) = param(11.1708)
# Flux.mse(predict(x), y) = param(11.1708)
# Flux.mse(predict(x), y) = param(11.0717)
# Flux.mse(predict(x), y) = param(11.0717)
# Flux.mse(predict(x), y) = param(10.9735)
# Flux.mse(predict(x), y) = param(10.9735)
# Flux.mse(predict(x), y) = param(10.8762)
# Flux.mse(predict(x), y) = param(10.8762)
# Flux.mse(predict(x), y) = param(10.7799)
# Flux.mse(predict(x), y) = param(10.7799)
# Flux.mse(predict(x), y) = param(10.6844)
# Flux.mse(predict(x), y) = param(10.6844)
# Flux.mse(predict(x), y) = param(10.5898)
# Flux.mse(predict(x), y) = param(10.5898)
# Flux.mse(predict(x), y) = param(10.4961)
# Flux.mse(predict(x), y) = param(10.4961)
# Flux.mse(predict(x), y) = param(10.4033)
# Flux.mse(predict(x), y) = param(10.4033)
# Flux.mse(predict(x), y) = param(10.3114)
# Flux.mse(predict(x), y) = param(10.3114)
# Flux.mse(predict(x), y) = param(10.2203)
# Flux.mse(predict(x), y) = param(10.2203)
# Flux.mse(predict(x), y) = param(10.13)
# Flux.mse(predict(x), y) = param(10.13)
# Flux.mse(predict(x), y) = param(10.0406)
# Flux.mse(predict(x), y) = param(10.0406)
# Flux.mse(predict(x), y) = param(9.95206)
# Flux.mse(predict(x), y) = param(9.95206)
# Flux.mse(predict(x), y) = param(9.86431)
# Flux.mse(predict(x), y) = param(9.86431)
# Flux.mse(predict(x), y) = param(9.77736)
# Flux.mse(predict(x), y) = param(9.77736)
# Flux.mse(predict(x), y) = param(9.69123)
# Flux.mse(predict(x), y) = param(9.69123)
# Flux.mse(predict(x), y) = param(9.60589)
# Flux.mse(predict(x), y) = param(9.60589)
# Flux.mse(predict(x), y) = param(9.52134)
# Flux.mse(predict(x), y) = param(9.52134)
# Flux.mse(predict(x), y) = param(9.43757)
# Flux.mse(predict(x), y) = param(9.43757)
# Flux.mse(predict(x), y) = param(9.35457)
# Flux.mse(predict(x), y) = param(9.35457)
# Flux.mse(predict(x), y) = param(9.27234)
# Flux.mse(predict(x), y) = param(9.27234)
# Flux.mse(predict(x), y) = param(9.19087)
# Flux.mse(predict(x), y) = param(9.19087)
# Flux.mse(predict(x), y) = param(9.11015)
# Flux.mse(predict(x), y) = param(9.11015)
# Flux.mse(predict(x), y) = param(9.03017)
# Flux.mse(predict(x), y) = param(9.03017)
# Flux.mse(predict(x), y) = param(8.95093)
# Flux.mse(predict(x), y) = param(8.95093)
# Flux.mse(predict(x), y) = param(8.87241)
# Flux.mse(predict(x), y) = param(8.87241)
# Flux.mse(predict(x), y) = param(8.79462)
# Flux.mse(predict(x), y) = param(8.79462)
# Flux.mse(predict(x), y) = param(8.71754)
# Flux.mse(predict(x), y) = param(8.71754)
# Flux.mse(predict(x), y) = param(8.64117)
# Flux.mse(predict(x), y) = param(8.64117)
# Flux.mse(predict(x), y) = param(8.5655)
# Flux.mse(predict(x), y) = param(8.5655)
# Flux.mse(predict(x), y) = param(8.49053)
# Flux.mse(predict(x), y) = param(8.49053)
# Flux.mse(predict(x), y) = param(8.41624)
# Flux.mse(predict(x), y) = param(8.41624)
# Flux.mse(predict(x), y) = param(8.34263)
# Flux.mse(predict(x), y) = param(8.34263)
# Flux.mse(predict(x), y) = param(8.26969)
# Flux.mse(predict(x), y) = param(8.26969)
# Flux.mse(predict(x), y) = param(8.19742)
# Flux.mse(predict(x), y) = param(8.19742)
# Flux.mse(predict(x), y) = param(8.12581)
# Flux.mse(predict(x), y) = param(8.12581)
# Flux.mse(predict(x), y) = param(8.05485)
# Flux.mse(predict(x), y) = param(8.05485)
# Flux.mse(predict(x), y) = param(7.98454)
# Flux.mse(predict(x), y) = param(7.98454)
# Flux.mse(predict(x), y) = param(7.91487)
# Flux.mse(predict(x), y) = param(7.91487)
# Flux.mse(predict(x), y) = param(7.84583)
# Flux.mse(predict(x), y) = param(7.84583)
# Flux.mse(predict(x), y) = param(7.77743)
# Flux.mse(predict(x), y) = param(7.77743)
# Flux.mse(predict(x), y) = param(7.70964)
# Flux.mse(predict(x), y) = param(7.70964)
# Flux.mse(predict(x), y) = param(7.64248)
# Flux.mse(predict(x), y) = param(7.64248)
# Flux.mse(predict(x), y) = param(7.57592)
# Flux.mse(predict(x), y) = param(7.57592)
# Flux.mse(predict(x), y) = param(7.50996)
# Flux.mse(predict(x), y) = param(7.50996)
# Flux.mse(predict(x), y) = param(7.44461)
# Flux.mse(predict(x), y) = param(7.44461)
# Flux.mse(predict(x), y) = param(7.37984)
# Flux.mse(predict(x), y) = param(7.37984)
# Flux.mse(predict(x), y) = param(7.31567)
# Flux.mse(predict(x), y) = param(7.31567)
# Flux.mse(predict(x), y) = param(7.25207)
# Flux.mse(predict(x), y) = param(7.25207)
# Flux.mse(predict(x), y) = param(7.18905)
# Flux.mse(predict(x), y) = param(7.18905)
# Flux.mse(predict(x), y) = param(7.1266)
# Flux.mse(predict(x), y) = param(7.1266)
# Flux.mse(predict(x), y) = param(7.06471)
# Flux.mse(predict(x), y) = param(7.06471)
# Flux.mse(predict(x), y) = param(7.00338)
# Flux.mse(predict(x), y) = param(7.00338)
# Flux.mse(predict(x), y) = param(6.94261)
# Flux.mse(predict(x), y) = param(6.94261)
# Flux.mse(predict(x), y) = param(6.88238)
# Flux.mse(predict(x), y) = param(6.88238)
# Flux.mse(predict(x), y) = param(6.8227)
# Flux.mse(predict(x), y) = param(6.8227)
# Flux.mse(predict(x), y) = param(6.76355)
# Flux.mse(predict(x), y) = param(6.76355)
# Flux.mse(predict(x), y) = param(6.70494)
# Flux.mse(predict(x), y) = param(6.70494)
# Flux.mse(predict(x), y) = param(6.64685)
# Flux.mse(predict(x), y) = param(6.64685)
# Flux.mse(predict(x), y) = param(6.58929)
# Flux.mse(predict(x), y) = param(6.58929)
# Flux.mse(predict(x), y) = param(6.53224)
# Flux.mse(predict(x), y) = param(6.53224)
# Flux.mse(predict(x), y) = param(6.47571)
# Flux.mse(predict(x), y) = param(6.47571)
# Flux.mse(predict(x), y) = param(6.41968)
# Flux.mse(predict(x), y) = param(6.41968)
# Flux.mse(predict(x), y) = param(6.36415)
# Flux.mse(predict(x), y) = param(6.36415)
# Flux.mse(predict(x), y) = param(6.30913)
# Flux.mse(predict(x), y) = param(6.30913)
# Flux.mse(predict(x), y) = param(6.25459)
# Flux.mse(predict(x), y) = param(6.25459)
# Flux.mse(predict(x), y) = param(6.20054)
# Flux.mse(predict(x), y) = param(6.20054)
# Flux.mse(predict(x), y) = param(6.14698)
# Flux.mse(predict(x), y) = param(6.14698)
# Flux.mse(predict(x), y) = param(6.0939)
# Flux.mse(predict(x), y) = param(6.0939)
# Flux.mse(predict(x), y) = param(6.04129)
# Flux.mse(predict(x), y) = param(6.04129)
# Flux.mse(predict(x), y) = param(5.98914)
# Flux.mse(predict(x), y) = param(5.98914)
# Flux.mse(predict(x), y) = param(5.93747)
# Flux.mse(predict(x), y) = param(5.93747)
# Flux.mse(predict(x), y) = param(5.88625)
# Flux.mse(predict(x), y) = param(5.88625)
# Flux.mse(predict(x), y) = param(5.8355)
# Flux.mse(predict(x), y) = param(5.8355)
# Flux.mse(predict(x), y) = param(5.78519)
# Flux.mse(predict(x), y) = param(5.78519)
# Flux.mse(predict(x), y) = param(5.73533)
# Flux.mse(predict(x), y) = param(5.73533)
# Flux.mse(predict(x), y) = param(5.68592)
# Flux.mse(predict(x), y) = param(5.68592)
# Flux.mse(predict(x), y) = param(5.63694)
# Flux.mse(predict(x), y) = param(5.63694)
# Flux.mse(predict(x), y) = param(5.5884)
# Flux.mse(predict(x), y) = param(5.5884)
# Flux.mse(predict(x), y) = param(5.54029)
# Flux.mse(predict(x), y) = param(5.54029)
# Flux.mse(predict(x), y) = param(5.49261)
# Flux.mse(predict(x), y) = param(5.49261)
# Flux.mse(predict(x), y) = param(5.44535)
# Flux.mse(predict(x), y) = param(5.44535)
# Flux.mse(predict(x), y) = param(5.39851)
# Flux.mse(predict(x), y) = param(5.39851)
# Flux.mse(predict(x), y) = param(5.35209)
# Flux.mse(predict(x), y) = param(5.35209)
# Flux.mse(predict(x), y) = param(5.30608)
# Flux.mse(predict(x), y) = param(5.30608)
# Flux.mse(predict(x), y) = param(5.26047)
# Flux.mse(predict(x), y) = param(5.26047)
# Flux.mse(predict(x), y) = param(5.21527)
# Flux.mse(predict(x), y) = param(5.21527)
# Flux.mse(predict(x), y) = param(5.17046)
# Flux.mse(predict(x), y) = param(5.17046)
# Flux.mse(predict(x), y) = param(5.12606)
# Flux.mse(predict(x), y) = param(5.12606)
# Flux.mse(predict(x), y) = param(5.08204)
# Flux.mse(predict(x), y) = param(5.08204)
# Flux.mse(predict(x), y) = param(5.03841)
# Flux.mse(predict(x), y) = param(5.03841)
# Flux.mse(predict(x), y) = param(4.99517)
# Flux.mse(predict(x), y) = param(4.99517)
# Flux.mse(predict(x), y) = param(4.95231)
# Flux.mse(predict(x), y) = param(4.95231)
# Flux.mse(predict(x), y) = param(4.90983)
# Flux.mse(predict(x), y) = param(4.90983)
# Flux.mse(predict(x), y) = param(4.86772)
# Flux.mse(predict(x), y) = param(4.86772)
# Flux.mse(predict(x), y) = param(4.82598)
# Flux.mse(predict(x), y) = param(4.82598)
# Flux.mse(predict(x), y) = param(4.78461)
# Flux.mse(predict(x), y) = param(4.78461)
# Flux.mse(predict(x), y) = param(4.74361)
# Flux.mse(predict(x), y) = param(4.74361)
# Flux.mse(predict(x), y) = param(4.70296)
# Flux.mse(predict(x), y) = param(4.70296)
# Flux.mse(predict(x), y) = param(4.66267)
# Flux.mse(predict(x), y) = param(4.66267)
# Flux.mse(predict(x), y) = param(4.62273)
# Flux.mse(predict(x), y) = param(4.62273)
# Flux.mse(predict(x), y) = param(4.58315)
# Flux.mse(predict(x), y) = param(4.58315)
# Flux.mse(predict(x), y) = param(4.54391)
# Flux.mse(predict(x), y) = param(4.54391)
# Flux.mse(predict(x), y) = param(4.50502)
# Flux.mse(predict(x), y) = param(4.50502)
# Flux.mse(predict(x), y) = param(4.46646)
# Flux.mse(predict(x), y) = param(4.46646)
# Flux.mse(predict(x), y) = param(4.42825)
# Flux.mse(predict(x), y) = param(4.42825)
# Flux.mse(predict(x), y) = param(4.39037)
# Flux.mse(predict(x), y) = param(4.39037)
# Flux.mse(predict(x), y) = param(4.35282)
# Flux.mse(predict(x), y) = param(4.35282)
# Flux.mse(predict(x), y) = param(4.3156)
# Flux.mse(predict(x), y) = param(4.3156)
# Flux.mse(predict(x), y) = param(4.2787)
# Flux.mse(predict(x), y) = param(4.2787)
# Flux.mse(predict(x), y) = param(4.24213)
# Flux.mse(predict(x), y) = param(4.24213)
# Flux.mse(predict(x), y) = param(4.20587)
# Flux.mse(predict(x), y) = param(4.20587)
# Flux.mse(predict(x), y) = param(4.16993)
# Flux.mse(predict(x), y) = param(4.16993)
# Flux.mse(predict(x), y) = param(4.13431)
# Flux.mse(predict(x), y) = param(4.13431)
# Flux.mse(predict(x), y) = param(4.09899)
# Flux.mse(predict(x), y) = param(4.09899)
# Flux.mse(predict(x), y) = param(4.06399)
# Flux.mse(predict(x), y) = param(4.06399)
# Flux.mse(predict(x), y) = param(4.02929)
# Flux.mse(predict(x), y) = param(4.02929)
# Flux.mse(predict(x), y) = param(3.99489)
# Flux.mse(predict(x), y) = param(3.99489)
# Flux.mse(predict(x), y) = param(3.96079)
# Flux.mse(predict(x), y) = param(3.96079)
# Flux.mse(predict(x), y) = param(3.92698)
# Flux.mse(predict(x), y) = param(3.92698)
# Flux.mse(predict(x), y) = param(3.89347)
# Flux.mse(predict(x), y) = param(3.89347)
# Flux.mse(predict(x), y) = param(3.86026)
# Flux.mse(predict(x), y) = param(3.86026)
# Flux.mse(predict(x), y) = param(3.82733)
# Flux.mse(predict(x), y) = param(3.82733)
# Flux.mse(predict(x), y) = param(3.79468)
# Flux.mse(predict(x), y) = param(3.79468)
# Flux.mse(predict(x), y) = param(3.76232)
# Flux.mse(predict(x), y) = param(3.76232)
# Flux.mse(predict(x), y) = param(3.73024)
# Flux.mse(predict(x), y) = param(3.73024)
# Flux.mse(predict(x), y) = param(3.69844)
# Flux.mse(predict(x), y) = param(3.69844)
# Flux.mse(predict(x), y) = param(3.66691)
# Flux.mse(predict(x), y) = param(3.66691)
# Flux.mse(predict(x), y) = param(3.63566)
# Flux.mse(predict(x), y) = param(3.63566)
# Flux.mse(predict(x), y) = param(3.60468)
# Flux.mse(predict(x), y) = param(3.60468)
# Flux.mse(predict(x), y) = param(3.57396)
# Flux.mse(predict(x), y) = param(3.57396)
# Flux.mse(predict(x), y) = param(3.54351)
# Flux.mse(predict(x), y) = param(3.54351)
# Flux.mse(predict(x), y) = param(3.51333)
# Flux.mse(predict(x), y) = param(3.51333)
# Flux.mse(predict(x), y) = param(3.48341)
# Flux.mse(predict(x), y) = param(3.48341)
# Flux.mse(predict(x), y) = param(3.45374)
# Flux.mse(predict(x), y) = param(3.45374)
# Flux.mse(predict(x), y) = param(3.42433)
# Flux.mse(predict(x), y) = param(3.42433)
# Flux.mse(predict(x), y) = param(3.39517)
# Flux.mse(predict(x), y) = param(3.39517)
# Flux.mse(predict(x), y) = param(3.36627)
# Flux.mse(predict(x), y) = param(3.36627)
# Flux.mse(predict(x), y) = param(3.33761)
# Flux.mse(predict(x), y) = param(3.33761)
# Flux.mse(predict(x), y) = param(3.30921)
# Flux.mse(predict(x), y) = param(3.30921)
# Flux.mse(predict(x), y) = param(3.28104)
# Flux.mse(predict(x), y) = param(3.28104)
# Flux.mse(predict(x), y) = param(3.25312)
# Flux.mse(predict(x), y) = param(3.25312)
# Flux.mse(predict(x), y) = param(3.22544)
# Flux.mse(predict(x), y) = param(3.22544)
# Flux.mse(predict(x), y) = param(3.198)
# Flux.mse(predict(x), y) = param(3.198)
# Flux.mse(predict(x), y) = param(3.17079)
# Flux.mse(predict(x), y) = param(3.17079)
# Flux.mse(predict(x), y) = param(3.14382)
# Flux.mse(predict(x), y) = param(3.14382)
# Flux.mse(predict(x), y) = param(3.11708)
# Flux.mse(predict(x), y) = param(3.11708)
# Flux.mse(predict(x), y) = param(3.09057)
# Flux.mse(predict(x), y) = param(3.09057)
# Flux.mse(predict(x), y) = param(3.06429)
# Flux.mse(predict(x), y) = param(3.06429)
# Flux.mse(predict(x), y) = param(3.03823)
# Flux.mse(predict(x), y) = param(3.03823)
# Flux.mse(predict(x), y) = param(3.0124)
# Flux.mse(predict(x), y) = param(3.0124)
# Flux.mse(predict(x), y) = param(2.98679)
# Flux.mse(predict(x), y) = param(2.98679)
# Flux.mse(predict(x), y) = param(2.9614)
# Flux.mse(predict(x), y) = param(2.9614)
# Flux.mse(predict(x), y) = param(2.93622)
# Flux.mse(predict(x), y) = param(2.93622)
# Flux.mse(predict(x), y) = param(2.91127)
# Flux.mse(predict(x), y) = param(2.91127)
# Flux.mse(predict(x), y) = param(2.88652)
# Flux.mse(predict(x), y) = param(2.88652)
# Flux.mse(predict(x), y) = param(2.86199)
# Flux.mse(predict(x), y) = param(2.86199)
# Flux.mse(predict(x), y) = param(2.83767)
# Flux.mse(predict(x), y) = param(2.83767)
# Flux.mse(predict(x), y) = param(2.81355)
# Flux.mse(predict(x), y) = param(2.81355)
# Flux.mse(predict(x), y) = param(2.78965)
# Flux.mse(predict(x), y) = param(2.78965)
# Flux.mse(predict(x), y) = param(2.76594)
# Flux.mse(predict(x), y) = param(2.76594)
# Flux.mse(predict(x), y) = param(2.74244)
# Flux.mse(predict(x), y) = param(2.74244)
# Flux.mse(predict(x), y) = param(2.71914)
# Flux.mse(predict(x), y) = param(2.71914)
# Flux.mse(predict(x), y) = param(2.69604)
# Flux.mse(predict(x), y) = param(2.69604)
# Flux.mse(predict(x), y) = param(2.67314)
# Flux.mse(predict(x), y) = param(2.67314)
# Flux.mse(predict(x), y) = param(2.65043)
# Flux.mse(predict(x), y) = param(2.65043)
# Flux.mse(predict(x), y) = param(2.62792)
# Flux.mse(predict(x), y) = param(2.62792)
# Flux.mse(predict(x), y) = param(2.60559)
# Flux.mse(predict(x), y) = param(2.60559)
# Flux.mse(predict(x), y) = param(2.58346)
# Flux.mse(predict(x), y) = param(2.58346)
# Flux.mse(predict(x), y) = param(2.56152)
# Flux.mse(predict(x), y) = param(2.56152)
# Flux.mse(predict(x), y) = param(2.53976)
# Flux.mse(predict(x), y) = param(2.53976)
# Flux.mse(predict(x), y) = param(2.51819)
# Flux.mse(predict(x), y) = param(2.51819)
# Flux.mse(predict(x), y) = param(2.49681)
# Flux.mse(predict(x), y) = param(2.49681)
# Flux.mse(predict(x), y) = param(2.4756)
# Flux.mse(predict(x), y) = param(2.4756)
# Flux.mse(predict(x), y) = param(2.45458)
# Flux.mse(predict(x), y) = param(2.45458)
# Flux.mse(predict(x), y) = param(2.43373)
# Flux.mse(predict(x), y) = param(2.43373)
# Flux.mse(predict(x), y) = param(2.41307)
# Flux.mse(predict(x), y) = param(2.41307)
# Flux.mse(predict(x), y) = param(2.39257)
# Flux.mse(predict(x), y) = param(2.39257)
# Flux.mse(predict(x), y) = param(2.37226)
# Flux.mse(predict(x), y) = param(2.37226)
# Flux.mse(predict(x), y) = param(2.35211)
# Flux.mse(predict(x), y) = param(2.35211)
# Flux.mse(predict(x), y) = param(2.33214)
# Flux.mse(predict(x), y) = param(2.33214)
# Flux.mse(predict(x), y) = param(2.31233)
# Flux.mse(predict(x), y) = param(2.31233)
# Flux.mse(predict(x), y) = param(2.2927)
# Flux.mse(predict(x), y) = param(2.2927)
# Flux.mse(predict(x), y) = param(2.27323)
# Flux.mse(predict(x), y) = param(2.27323)
# Flux.mse(predict(x), y) = param(2.25393)
# Flux.mse(predict(x), y) = param(2.25393)
# Flux.mse(predict(x), y) = param(2.23479)
# Flux.mse(predict(x), y) = param(2.23479)
# Flux.mse(predict(x), y) = param(2.21581)
# Flux.mse(predict(x), y) = param(2.21581)
# Flux.mse(predict(x), y) = param(2.19699)
# Flux.mse(predict(x), y) = param(2.19699)
# Flux.mse(predict(x), y) = param(2.17833)
# Flux.mse(predict(x), y) = param(2.17833)
# Flux.mse(predict(x), y) = param(2.15984)
# Flux.mse(predict(x), y) = param(2.15984)
# Flux.mse(predict(x), y) = param(2.14149)
# Flux.mse(predict(x), y) = param(2.14149)
# Flux.mse(predict(x), y) = param(2.12331)
# Flux.mse(predict(x), y) = param(2.12331)
# Flux.mse(predict(x), y) = param(2.10527)
# Flux.mse(predict(x), y) = param(2.10527)
# Flux.mse(predict(x), y) = param(2.08739)
# Flux.mse(predict(x), y) = param(2.08739)
# Flux.mse(predict(x), y) = param(2.06966)
# Flux.mse(predict(x), y) = param(2.06966)
# Flux.mse(predict(x), y) = param(2.05209)
# Flux.mse(predict(x), y) = param(2.05209)
# Flux.mse(predict(x), y) = param(2.03466)
# Flux.mse(predict(x), y) = param(2.03466)
# Flux.mse(predict(x), y) = param(2.01737)
# Flux.mse(predict(x), y) = param(2.01737)
# Flux.mse(predict(x), y) = param(2.00024)
# Flux.mse(predict(x), y) = param(2.00024)
# Flux.mse(predict(x), y) = param(1.98325)
# Flux.mse(predict(x), y) = param(1.98325)
# Flux.mse(predict(x), y) = param(1.9664)
# Flux.mse(predict(x), y) = param(1.9664)
# Flux.mse(predict(x), y) = param(1.94969)
# Flux.mse(predict(x), y) = param(1.94969)
# Flux.mse(predict(x), y) = param(1.93313)
# Flux.mse(predict(x), y) = param(1.93313)
# Flux.mse(predict(x), y) = param(1.9167)
# Flux.mse(predict(x), y) = param(1.9167)
# Flux.mse(predict(x), y) = param(1.90042)
# Flux.mse(predict(x), y) = param(1.90042)
# Flux.mse(predict(x), y) = param(1.88427)
# Flux.mse(predict(x), y) = param(1.88427)
# Flux.mse(predict(x), y) = param(1.86826)
# Flux.mse(predict(x), y) = param(1.86826)
# Flux.mse(predict(x), y) = param(1.85238)
# Flux.mse(predict(x), y) = param(1.85238)
# Flux.mse(predict(x), y) = param(1.83664)
# Flux.mse(predict(x), y) = param(1.83664)
# Flux.mse(predict(x), y) = param(1.82103)
# Flux.mse(predict(x), y) = param(1.82103)
# Flux.mse(predict(x), y) = param(1.80555)
# Flux.mse(predict(x), y) = param(1.80555)
# Flux.mse(predict(x), y) = param(1.7902)
# Flux.mse(predict(x), y) = param(1.7902)
# Flux.mse(predict(x), y) = param(1.77498)
# Flux.mse(predict(x), y) = param(1.77498)
# Flux.mse(predict(x), y) = param(1.75989)
# Flux.mse(predict(x), y) = param(1.75989)
# Flux.mse(predict(x), y) = param(1.74493)
# Flux.mse(predict(x), y) = param(1.74493)
# Flux.mse(predict(x), y) = param(1.73009)
# Flux.mse(predict(x), y) = param(1.73009)
# Flux.mse(predict(x), y) = param(1.71538)
# Flux.mse(predict(x), y) = param(1.71538)
# Flux.mse(predict(x), y) = param(1.7008)
# Flux.mse(predict(x), y) = param(1.7008)
# Flux.mse(predict(x), y) = param(1.68633)
# Flux.mse(predict(x), y) = param(1.68633)
# Flux.mse(predict(x), y) = param(1.67199)
# Flux.mse(predict(x), y) = param(1.67199)
# Flux.mse(predict(x), y) = param(1.65776)
# Flux.mse(predict(x), y) = param(1.65776)
# Flux.mse(predict(x), y) = param(1.64366)
# Flux.mse(predict(x), y) = param(1.64366)
# Flux.mse(predict(x), y) = param(1.62968)
# Flux.mse(predict(x), y) = param(1.62968)
# Flux.mse(predict(x), y) = param(1.61581)
# Flux.mse(predict(x), y) = param(1.61581)
# Flux.mse(predict(x), y) = param(1.60206)
# Flux.mse(predict(x), y) = param(1.60206)
# Flux.mse(predict(x), y) = param(1.58843)
# Flux.mse(predict(x), y) = param(1.58843)
# Flux.mse(predict(x), y) = param(1.57491)
# Flux.mse(predict(x), y) = param(1.57491)
# Flux.mse(predict(x), y) = param(1.5615)
# Flux.mse(predict(x), y) = param(1.5615)
# Flux.mse(predict(x), y) = param(1.54821)
# Flux.mse(predict(x), y) = param(1.54821)
# Flux.mse(predict(x), y) = param(1.53503)
# Flux.mse(predict(x), y) = param(1.53503)
# Flux.mse(predict(x), y) = param(1.52196)
# Flux.mse(predict(x), y) = param(1.52196)
# Flux.mse(predict(x), y) = param(1.509)
# Flux.mse(predict(x), y) = param(1.509)
# Flux.mse(predict(x), y) = param(1.49615)
# Flux.mse(predict(x), y) = param(1.49615)
# Flux.mse(predict(x), y) = param(1.4834)
# Flux.mse(predict(x), y) = param(1.4834)
# Flux.mse(predict(x), y) = param(1.47076)
# Flux.mse(predict(x), y) = param(1.47076)
# Flux.mse(predict(x), y) = param(1.45823)
# Flux.mse(predict(x), y) = param(1.45823)
# Flux.mse(predict(x), y) = param(1.44581)
# Flux.mse(predict(x), y) = param(1.44581)
# Flux.mse(predict(x), y) = param(1.43349)
# Flux.mse(predict(x), y) = param(1.43349)
# Flux.mse(predict(x), y) = param(1.42127)
# Flux.mse(predict(x), y) = param(1.42127)
# Flux.mse(predict(x), y) = param(1.40916)
# Flux.mse(predict(x), y) = param(1.40916)
# Flux.mse(predict(x), y) = param(1.39714)
# Flux.mse(predict(x), y) = param(1.39714)
# Flux.mse(predict(x), y) = param(1.38523)
# Flux.mse(predict(x), y) = param(1.38523)
# Flux.mse(predict(x), y) = param(1.37342)
# Flux.mse(predict(x), y) = param(1.37342)
# Flux.mse(predict(x), y) = param(1.3617)
# Flux.mse(predict(x), y) = param(1.3617)
# Flux.mse(predict(x), y) = param(1.35009)
# Flux.mse(predict(x), y) = param(1.35009)
# Flux.mse(predict(x), y) = param(1.33857)
# Flux.mse(predict(x), y) = param(1.33857)
# Flux.mse(predict(x), y) = param(1.32715)
# Flux.mse(predict(x), y) = param(1.32715)
# Flux.mse(predict(x), y) = param(1.31582)
# Flux.mse(predict(x), y) = param(1.31582)
# Flux.mse(predict(x), y) = param(1.30459)
# Flux.mse(predict(x), y) = param(1.30459)
# Flux.mse(predict(x), y) = param(1.29346)
# Flux.mse(predict(x), y) = param(1.29346)
# Flux.mse(predict(x), y) = param(1.28241)
# Flux.mse(predict(x), y) = param(1.28241)
# Flux.mse(predict(x), y) = param(1.27146)
# Flux.mse(predict(x), y) = param(1.27146)
# Flux.mse(predict(x), y) = param(1.26061)
# Flux.mse(predict(x), y) = param(1.26061)
# Flux.mse(predict(x), y) = param(1.24984)
# Flux.mse(predict(x), y) = param(1.24984)
# Flux.mse(predict(x), y) = param(1.23916)
# Flux.mse(predict(x), y) = param(1.23916)
# Flux.mse(predict(x), y) = param(1.22857)
# Flux.mse(predict(x), y) = param(1.22857)
# Flux.mse(predict(x), y) = param(1.21807)
# Flux.mse(predict(x), y) = param(1.21807)
# Flux.mse(predict(x), y) = param(1.20766)
# Flux.mse(predict(x), y) = param(1.20766)
# Flux.mse(predict(x), y) = param(1.19734)
# Flux.mse(predict(x), y) = param(1.19734)
# Flux.mse(predict(x), y) = param(1.1871)
# Flux.mse(predict(x), y) = param(1.1871)
# Flux.mse(predict(x), y) = param(1.17695)
# Flux.mse(predict(x), y) = param(1.17695)
# Flux.mse(predict(x), y) = param(1.16688)
# Flux.mse(predict(x), y) = param(1.16688)
# Flux.mse(predict(x), y) = param(1.1569)
# Flux.mse(predict(x), y) = param(1.1569)
# Flux.mse(predict(x), y) = param(1.147)
# Flux.mse(predict(x), y) = param(1.147)
# Flux.mse(predict(x), y) = param(1.13719)
# Flux.mse(predict(x), y) = param(1.13719)
# Flux.mse(predict(x), y) = param(1.12745)
# Flux.mse(predict(x), y) = param(1.12745)
# Flux.mse(predict(x), y) = param(1.1178)
# Flux.mse(predict(x), y) = param(1.1178)
# Flux.mse(predict(x), y) = param(1.10823)
# Flux.mse(predict(x), y) = param(1.10823)
# Flux.mse(predict(x), y) = param(1.09874)
# Flux.mse(predict(x), y) = param(1.09874)
# Flux.mse(predict(x), y) = param(1.08933)
# Flux.mse(predict(x), y) = param(1.08933)
# Flux.mse(predict(x), y) = param(1.08)
# Flux.mse(predict(x), y) = param(1.08)
# Flux.mse(predict(x), y) = param(1.07074)
# Flux.mse(predict(x), y) = param(1.07074)
# Flux.mse(predict(x), y) = param(1.06156)
# Flux.mse(predict(x), y) = param(1.06156)
# Flux.mse(predict(x), y) = param(1.05246)
# Flux.mse(predict(x), y) = param(1.05246)
# Flux.mse(predict(x), y) = param(1.04344)
# Flux.mse(predict(x), y) = param(1.04344)
# Flux.mse(predict(x), y) = param(1.03449)
# Flux.mse(predict(x), y) = param(1.03449)
# Flux.mse(predict(x), y) = param(1.02562)
# Flux.mse(predict(x), y) = param(1.02562)
# Flux.mse(predict(x), y) = param(1.01682)
# Flux.mse(predict(x), y) = param(1.01682)
# Flux.mse(predict(x), y) = param(1.00809)
# Flux.mse(predict(x), y) = param(1.00809)
# Flux.mse(predict(x), y) = param(0.999439)
# Flux.mse(predict(x), y) = param(0.999439)
# Flux.mse(predict(x), y) = param(0.990859)
# Flux.mse(predict(x), y) = param(0.990859)
# Flux.mse(predict(x), y) = param(0.982351)
# Flux.mse(predict(x), y) = param(0.982351)
# Flux.mse(predict(x), y) = param(0.973914)
# Flux.mse(predict(x), y) = param(0.973914)
# Flux.mse(predict(x), y) = param(0.965547)
# Flux.mse(predict(x), y) = param(0.965547)
# Flux.mse(predict(x), y) = param(0.957251)
# Flux.mse(predict(x), y) = param(0.957251)
# Flux.mse(predict(x), y) = param(0.949024)
# Flux.mse(predict(x), y) = param(0.949024)
# Flux.mse(predict(x), y) = param(0.940866)
# Flux.mse(predict(x), y) = param(0.940866)
# Flux.mse(predict(x), y) = param(0.932776)
# Flux.mse(predict(x), y) = param(0.932776)
# Flux.mse(predict(x), y) = param(0.924753)
# Flux.mse(predict(x), y) = param(0.924753)
# Flux.mse(predict(x), y) = param(0.916798)
# Flux.mse(predict(x), y) = param(0.916798)
# Flux.mse(predict(x), y) = param(0.90891)
# Flux.mse(predict(x), y) = param(0.90891)
# Flux.mse(predict(x), y) = param(0.901088)
# Flux.mse(predict(x), y) = param(0.901088)
# Flux.mse(predict(x), y) = param(0.893331)
# Flux.mse(predict(x), y) = param(0.893331)
# Flux.mse(predict(x), y) = param(0.885639)
# Flux.mse(predict(x), y) = param(0.885639)
# Flux.mse(predict(x), y) = param(0.878011)
# Flux.mse(predict(x), y) = param(0.878011)
# Flux.mse(predict(x), y) = param(0.870447)
# Flux.mse(predict(x), y) = param(0.870447)
# Flux.mse(predict(x), y) = param(0.862947)
# Flux.mse(predict(x), y) = param(0.862947)
# Flux.mse(predict(x), y) = param(0.85551)
# Flux.mse(predict(x), y) = param(0.85551)
# Flux.mse(predict(x), y) = param(0.848134)
# Flux.mse(predict(x), y) = param(0.848134)
# Flux.mse(predict(x), y) = param(0.840821)
# Flux.mse(predict(x), y) = param(0.840821)
# Flux.mse(predict(x), y) = param(0.833568)
# Flux.mse(predict(x), y) = param(0.833568)
# Flux.mse(predict(x), y) = param(0.826377)
# Flux.mse(predict(x), y) = param(0.826377)
# Flux.mse(predict(x), y) = param(0.819245)
# Flux.mse(predict(x), y) = param(0.819245)
# Flux.mse(predict(x), y) = param(0.812174)
# Flux.mse(predict(x), y) = param(0.812174)
# Flux.mse(predict(x), y) = param(0.805161)
# Flux.mse(predict(x), y) = param(0.805161)
# Flux.mse(predict(x), y) = param(0.798207)
# Flux.mse(predict(x), y) = param(0.798207)
# Flux.mse(predict(x), y) = param(0.791312)
# Flux.mse(predict(x), y) = param(0.791312)
# Flux.mse(predict(x), y) = param(0.784474)
# Flux.mse(predict(x), y) = param(0.784474)
# Flux.mse(predict(x), y) = param(0.777694)
# Flux.mse(predict(x), y) = param(0.777694)
# Flux.mse(predict(x), y) = param(0.77097)
# Flux.mse(predict(x), y) = param(0.77097)
# Flux.mse(predict(x), y) = param(0.764303)
# Flux.mse(predict(x), y) = param(0.764303)
# Flux.mse(predict(x), y) = param(0.757691)
# Flux.mse(predict(x), y) = param(0.757691)
# Flux.mse(predict(x), y) = param(0.751135)
# Flux.mse(predict(x), y) = param(0.751135)
# Flux.mse(predict(x), y) = param(0.744634)
# Flux.mse(predict(x), y) = param(0.744634)
# Flux.mse(predict(x), y) = param(0.738188)
# Flux.mse(predict(x), y) = param(0.738188)
# Flux.mse(predict(x), y) = param(0.731795)
# Flux.mse(predict(x), y) = param(0.731795)
# Flux.mse(predict(x), y) = param(0.725456)
# Flux.mse(predict(x), y) = param(0.725456)
# Flux.mse(predict(x), y) = param(0.71917)
# Flux.mse(predict(x), y) = param(0.71917)
# Flux.mse(predict(x), y) = param(0.712937)
# Flux.mse(predict(x), y) = param(0.712937)
# Flux.mse(predict(x), y) = param(0.706756)
# Flux.mse(predict(x), y) = param(0.706756)
# Flux.mse(predict(x), y) = param(0.700627)
# Flux.mse(predict(x), y) = param(0.700627)
# Flux.mse(predict(x), y) = param(0.694549)
# Flux.mse(predict(x), y) = param(0.694549)
# Flux.mse(predict(x), y) = param(0.688522)
# Flux.mse(predict(x), y) = param(0.688522)
# Flux.mse(predict(x), y) = param(0.682546)
# Flux.mse(predict(x), y) = param(0.682546)
# Flux.mse(predict(x), y) = param(0.67662)
# Flux.mse(predict(x), y) = param(0.67662)
# Flux.mse(predict(x), y) = param(0.670744)
# Flux.mse(predict(x), y) = param(0.670744)
# Flux.mse(predict(x), y) = param(0.664916)
# Flux.mse(predict(x), y) = param(0.664916)
# Flux.mse(predict(x), y) = param(0.659138)
# Flux.mse(predict(x), y) = param(0.659138)
# Flux.mse(predict(x), y) = param(0.653408)
# Flux.mse(predict(x), y) = param(0.653408)
# Flux.mse(predict(x), y) = param(0.647727)
# Flux.mse(predict(x), y) = param(0.647727)
# Flux.mse(predict(x), y) = param(0.642093)
# Flux.mse(predict(x), y) = param(0.642093)
# Flux.mse(predict(x), y) = param(0.636506)
# Flux.mse(predict(x), y) = param(0.636506)
# Flux.mse(predict(x), y) = param(0.630966)
# Flux.mse(predict(x), y) = param(0.630966)
# Flux.mse(predict(x), y) = param(0.625473)
# Flux.mse(predict(x), y) = param(0.625473)
# Flux.mse(predict(x), y) = param(0.620026)
# Flux.mse(predict(x), y) = param(0.620026)
# Flux.mse(predict(x), y) = param(0.614625)
# Flux.mse(predict(x), y) = param(0.614625)
# Flux.mse(predict(x), y) = param(0.609269)
# Flux.mse(predict(x), y) = param(0.609269)
# Flux.mse(predict(x), y) = param(0.603957)
# Flux.mse(predict(x), y) = param(0.603957)
# Flux.mse(predict(x), y) = param(0.598691)
# Flux.mse(predict(x), y) = param(0.598691)
# Flux.mse(predict(x), y) = param(0.593469)
# Flux.mse(predict(x), y) = param(0.593469)
# Flux.mse(predict(x), y) = param(0.588291)
# Flux.mse(predict(x), y) = param(0.588291)
# Flux.mse(predict(x), y) = param(0.583156)
# Flux.mse(predict(x), y) = param(0.583156)
# Flux.mse(predict(x), y) = param(0.578064)
# Flux.mse(predict(x), y) = param(0.578064)
# Flux.mse(predict(x), y) = param(0.573015)
# Flux.mse(predict(x), y) = param(0.573015)
# Flux.mse(predict(x), y) = param(0.568009)
# Flux.mse(predict(x), y) = param(0.568009)
# Flux.mse(predict(x), y) = param(0.563045)
# Flux.mse(predict(x), y) = param(0.563045)
# Flux.mse(predict(x), y) = param(0.558122)
# Flux.mse(predict(x), y) = param(0.558122)
# Flux.mse(predict(x), y) = param(0.553241)
# Flux.mse(predict(x), y) = param(0.553241)
# Flux.mse(predict(x), y) = param(0.548401)
# Flux.mse(predict(x), y) = param(0.548401)
# Flux.mse(predict(x), y) = param(0.543602)
# Flux.mse(predict(x), y) = param(0.543602)
# Flux.mse(predict(x), y) = param(0.538843)
# Flux.mse(predict(x), y) = param(0.538843)
# Flux.mse(predict(x), y) = param(0.534124)
# Flux.mse(predict(x), y) = param(0.534124)
# Flux.mse(predict(x), y) = param(0.529445)
# Flux.mse(predict(x), y) = param(0.529445)
# Flux.mse(predict(x), y) = param(0.524805)
# Flux.mse(predict(x), y) = param(0.524805)
# Flux.mse(predict(x), y) = param(0.520204)
# Flux.mse(predict(x), y) = param(0.520204)
# Flux.mse(predict(x), y) = param(0.515642)
# Flux.mse(predict(x), y) = param(0.515642)
# Flux.mse(predict(x), y) = param(0.511119)
# Flux.mse(predict(x), y) = param(0.511119)
# Flux.mse(predict(x), y) = param(0.506634)
# Flux.mse(predict(x), y) = param(0.506634)
# Flux.mse(predict(x), y) = param(0.502186)
# Flux.mse(predict(x), y) = param(0.502186)
# Flux.mse(predict(x), y) = param(0.497776)
# Flux.mse(predict(x), y) = param(0.497776)
# Flux.mse(predict(x), y) = param(0.493403)
# Flux.mse(predict(x), y) = param(0.493403)
# Flux.mse(predict(x), y) = param(0.489067)
# Flux.mse(predict(x), y) = param(0.489067)
# Flux.mse(predict(x), y) = param(0.484768)
# Flux.mse(predict(x), y) = param(0.484768)
# Flux.mse(predict(x), y) = param(0.480504)
# Flux.mse(predict(x), y) = param(0.480504)
# Flux.mse(predict(x), y) = param(0.476277)
# Flux.mse(predict(x), y) = param(0.476277)
# Flux.mse(predict(x), y) = param(0.472086)
# Flux.mse(predict(x), y) = param(0.472086)
# Flux.mse(predict(x), y) = param(0.467929)
# Flux.mse(predict(x), y) = param(0.467929)
# Flux.mse(predict(x), y) = param(0.463808)
# Flux.mse(predict(x), y) = param(0.463808)
# Flux.mse(predict(x), y) = param(0.459722)
# Flux.mse(predict(x), y) = param(0.459722)
# Flux.mse(predict(x), y) = param(0.45567)
# Flux.mse(predict(x), y) = param(0.45567)
# Flux.mse(predict(x), y) = param(0.451653)
# Flux.mse(predict(x), y) = param(0.451653)
# Flux.mse(predict(x), y) = param(0.447669)
# Flux.mse(predict(x), y) = param(0.447669)
# ...
# Flux.mse(predict(x), y) = param(0.00108704)
# Flux.mse(predict(x), y) = param(0.00107341)
# Flux.mse(predict(x), y) = param(0.00107341)
# Flux.mse(predict(x), y) = param(0.00105993)
# Flux.mse(predict(x), y) = param(0.00105993)
# Flux.mse(predict(x), y) = param(0.00104662)
# Flux.mse(predict(x), y) = param(0.00104662)
# Flux.mse(predict(x), y) = param(0.00103346)
# Flux.mse(predict(x), y) = param(0.00103346)
# Flux.mse(predict(x), y) = param(0.00102046)
# Flux.mse(predict(x), y) = param(0.00102046)
# Flux.mse(predict(x), y) = param(0.00100762)
# Flux.mse(predict(x), y) = param(0.00100762)
# Flux.mse(predict(x), y) = param(0.000994925)
# Flux.mse(predict(x), y) = param(0.000994925)
# Flux.mse(predict(x), y) = param(0.000982383)
# Flux.mse(predict(x), y) = param(0.000982383)
# Flux.mse(predict(x), y) = param(0.000969991)
# Flux.mse(predict(x), y) = param(0.000969991)
# Flux.mse(predict(x), y) = param(0.000957746)
# Flux.mse(predict(x), y) = param(0.000957746)
# Flux.mse(predict(x), y) = param(0.000945647)
# Flux.mse(predict(x), y) = param(0.000945647)
# Flux.mse(predict(x), y) = param(0.000933693)
# Flux.mse(predict(x), y) = param(0.000933693)
# Flux.mse(predict(x), y) = param(0.000921881)
# Flux.mse(predict(x), y) = param(0.000921881)
# Flux.mse(predict(x), y) = param(0.000910211)
# Flux.mse(predict(x), y) = param(0.000910211)
# Flux.mse(predict(x), y) = param(0.00089868)
# Flux.mse(predict(x), y) = param(0.00089868)
# Flux.mse(predict(x), y) = param(0.000887287)
# Flux.mse(predict(x), y) = param(0.000887287)
# Flux.mse(predict(x), y) = param(0.00087603)
# Flux.mse(predict(x), y) = param(0.00087603)
# Flux.mse(predict(x), y) = param(0.000864908)
# Flux.mse(predict(x), y) = param(0.000864908)
# Flux.mse(predict(x), y) = param(0.00085392)
# Flux.mse(predict(x), y) = param(0.00085392)
# Flux.mse(predict(x), y) = param(0.000843064)
# Flux.mse(predict(x), y) = param(0.000843064)
# Flux.mse(predict(x), y) = param(0.000832338)
# Flux.mse(predict(x), y) = param(0.000832338)
# Flux.mse(predict(x), y) = param(0.000821741)
# Flux.mse(predict(x), y) = param(0.000821741)
# Flux.mse(predict(x), y) = param(0.000811271)
# Flux.mse(predict(x), y) = param(0.000811271)
# Flux.mse(predict(x), y) = param(0.000800928)
# Flux.mse(predict(x), y) = param(0.000800928)
# Flux.mse(predict(x), y) = param(0.000790709)
# Flux.mse(predict(x), y) = param(0.000790709)
# Flux.mse(predict(x), y) = param(0.000780613)
# Flux.mse(predict(x), y) = param(0.000780613)
# Flux.mse(predict(x), y) = param(0.000770639)
# Flux.mse(predict(x), y) = param(0.000770639)
# Flux.mse(predict(x), y) = param(0.000760786)
# Flux.mse(predict(x), y) = param(0.000760786)
# Flux.mse(predict(x), y) = param(0.000751052)
# Flux.mse(predict(x), y) = param(0.000751052)
# Flux.mse(predict(x), y) = param(0.000741435)
# Flux.mse(predict(x), y) = param(0.000741435)
# Flux.mse(predict(x), y) = param(0.000731935)
# Flux.mse(predict(x), y) = param(0.000731935)
# Flux.mse(predict(x), y) = param(0.000722549)
# Flux.mse(predict(x), y) = param(0.000722549)
# Flux.mse(predict(x), y) = param(0.000713278)
# Flux.mse(predict(x), y) = param(0.000713278)
# Flux.mse(predict(x), y) = param(0.000704119)
# Flux.mse(predict(x), y) = param(0.000704119)
# Flux.mse(predict(x), y) = param(0.000695071)
# Flux.mse(predict(x), y) = param(0.000695071)
# Flux.mse(predict(x), y) = param(0.000686133)
# Flux.mse(predict(x), y) = param(0.000686133)
# Flux.mse(predict(x), y) = param(0.000677304)
# Flux.mse(predict(x), y) = param(0.000677304)
# Flux.mse(predict(x), y) = param(0.000668582)
# Flux.mse(predict(x), y) = param(0.000668582)
# Flux.mse(predict(x), y) = param(0.000659967)
# Flux.mse(predict(x), y) = param(0.000659967)
# Flux.mse(predict(x), y) = param(0.000651456)
# Flux.mse(predict(x), y) = param(0.000651456)
# Flux.mse(predict(x), y) = param(0.000643049)
# Flux.mse(predict(x), y) = param(0.000643049)
# Flux.mse(predict(x), y) = param(0.000634745)
# Flux.mse(predict(x), y) = param(0.000634745)
# Flux.mse(predict(x), y) = param(0.000626542)
# Flux.mse(predict(x), y) = param(0.000626542)
# Flux.mse(predict(x), y) = param(0.00061844)
# Flux.mse(predict(x), y) = param(0.00061844)
# Flux.mse(predict(x), y) = param(0.000610436)
# Flux.mse(predict(x), y) = param(0.000610436)
# Flux.mse(predict(x), y) = param(0.000602531)
# Flux.mse(predict(x), y) = param(0.000602531)
# Flux.mse(predict(x), y) = param(0.000594722)
# Flux.mse(predict(x), y) = param(0.000594722)
# Flux.mse(predict(x), y) = param(0.000587009)
# Flux.mse(predict(x), y) = param(0.000587009)
# Flux.mse(predict(x), y) = param(0.000579391)
# Flux.mse(predict(x), y) = param(0.000579391)
# Flux.mse(predict(x), y) = param(0.000571866)
# Flux.mse(predict(x), y) = param(0.000571866)
# Flux.mse(predict(x), y) = param(0.000564433)
# Flux.mse(predict(x), y) = param(0.000564433)
# Flux.mse(predict(x), y) = param(0.000557092)
# Flux.mse(predict(x), y) = param(0.000557092)
# Flux.mse(predict(x), y) = param(0.000549842)
# Flux.mse(predict(x), y) = param(0.000549842)
# Flux.mse(predict(x), y) = param(0.00054268)
# Flux.mse(predict(x), y) = param(0.00054268)
# Flux.mse(predict(x), y) = param(0.000535607)
# Flux.mse(predict(x), y) = param(0.000535607)
# Flux.mse(predict(x), y) = param(0.000528621)
# Flux.mse(predict(x), y) = param(0.000528621)
# Flux.mse(predict(x), y) = param(0.000521722)
# Flux.mse(predict(x), y) = param(0.000521722)
# Flux.mse(predict(x), y) = param(0.000514907)
# Flux.mse(predict(x), y) = param(0.000514907)
# Flux.mse(predict(x), y) = param(0.000508177)
# Flux.mse(predict(x), y) = param(0.000508177)
# Flux.mse(predict(x), y) = param(0.00050153)
# Flux.mse(predict(x), y) = param(0.00050153)
# Flux.mse(predict(x), y) = param(0.000494965)
# Flux.mse(predict(x), y) = param(0.000494965)
# Flux.mse(predict(x), y) = param(0.000488482)
# Flux.mse(predict(x), y) = param(0.000488482)
# Flux.mse(predict(x), y) = param(0.000482079)
# Flux.mse(predict(x), y) = param(0.000482079)
# Flux.mse(predict(x), y) = param(0.000475755)
# Flux.mse(predict(x), y) = param(0.000475755)
# Flux.mse(predict(x), y) = param(0.00046951)
# Flux.mse(predict(x), y) = param(0.00046951)
# Flux.mse(predict(x), y) = param(0.000463343)
# Flux.mse(predict(x), y) = param(0.000463343)
# Flux.mse(predict(x), y) = param(0.000457252)
# Flux.mse(predict(x), y) = param(0.000457252)
# Flux.mse(predict(x), y) = param(0.000451237)
# Flux.mse(predict(x), y) = param(0.000451237)
# Flux.mse(predict(x), y) = param(0.000445297)
# Flux.mse(predict(x), y) = param(0.000445297)
# Flux.mse(predict(x), y) = param(0.000439431)
# Flux.mse(predict(x), y) = param(0.000439431)
# Flux.mse(predict(x), y) = param(0.000433638)
# Flux.mse(predict(x), y) = param(0.000433638)
# Flux.mse(predict(x), y) = param(0.000427918)
# Flux.mse(predict(x), y) = param(0.000427918)
# Flux.mse(predict(x), y) = param(0.000422269)
# Flux.mse(predict(x), y) = param(0.000422269)
# Flux.mse(predict(x), y) = param(0.00041669)
# Flux.mse(predict(x), y) = param(0.00041669)
# Flux.mse(predict(x), y) = param(0.000411182)
# Flux.mse(predict(x), y) = param(0.000411182)
# Flux.mse(predict(x), y) = param(0.000405742)
# Flux.mse(predict(x), y) = param(0.000405742)
# Flux.mse(predict(x), y) = param(0.00040037)
# Flux.mse(predict(x), y) = param(0.00040037)
# Flux.mse(predict(x), y) = param(0.000395066)
# Flux.mse(predict(x), y) = param(0.000395066)
# Flux.mse(predict(x), y) = param(0.000389828)
# Flux.mse(predict(x), y) = param(0.000389828)
# Flux.mse(predict(x), y) = param(0.000384657)
# Flux.mse(predict(x), y) = param(0.000384657)
# Flux.mse(predict(x), y) = param(0.00037955)
# Flux.mse(predict(x), y) = param(0.00037955)
# Flux.mse(predict(x), y) = param(0.000374507)
# Flux.mse(predict(x), y) = param(0.000374507)
# Flux.mse(predict(x), y) = param(0.000369528)
# Flux.mse(predict(x), y) = param(0.000369528)
# Flux.mse(predict(x), y) = param(0.000364611)
# Flux.mse(predict(x), y) = param(0.000364611)
# Flux.mse(predict(x), y) = param(0.000359757)
# Flux.mse(predict(x), y) = param(0.000359757)
# Flux.mse(predict(x), y) = param(0.000354963)
# Flux.mse(predict(x), y) = param(0.000354963)
# Flux.mse(predict(x), y) = param(0.000350231)
# Flux.mse(predict(x), y) = param(0.000350231)
# Flux.mse(predict(x), y) = param(0.000345558)
# Flux.mse(predict(x), y) = param(0.000345558)
# Flux.mse(predict(x), y) = param(0.000340944)
# Flux.mse(predict(x), y) = param(0.000340944)
# Flux.mse(predict(x), y) = param(0.000336388)
# Flux.mse(predict(x), y) = param(0.000336388)
# Flux.mse(predict(x), y) = param(0.00033189)
# Flux.mse(predict(x), y) = param(0.00033189)
# Flux.mse(predict(x), y) = param(0.00032745)
# Flux.mse(predict(x), y) = param(0.00032745)
# Flux.mse(predict(x), y) = param(0.000323065)
# Flux.mse(predict(x), y) = param(0.000323065)
# Flux.mse(predict(x), y) = param(0.000318736)
# Flux.mse(predict(x), y) = param(0.000318736)
# Flux.mse(predict(x), y) = param(0.000314462)
# Flux.mse(predict(x), y) = param(0.000314462)
# Flux.mse(predict(x), y) = param(0.000310243)
# Flux.mse(predict(x), y) = param(0.000310243)
# Flux.mse(predict(x), y) = param(0.000306077)
# Flux.mse(predict(x), y) = param(0.000306077)
# Flux.mse(predict(x), y) = param(0.000301964)
# Flux.mse(predict(x), y) = param(0.000301964)
# Flux.mse(predict(x), y) = param(0.000297903)
# Flux.mse(predict(x), y) = param(0.000297903)
# Flux.mse(predict(x), y) = param(0.000293894)
# Flux.mse(predict(x), y) = param(0.000293894)
# Flux.mse(predict(x), y) = param(0.000289937)
# Flux.mse(predict(x), y) = param(0.000289937)
# Flux.mse(predict(x), y) = param(0.00028603)
# Flux.mse(predict(x), y) = param(0.00028603)
# Flux.mse(predict(x), y) = param(0.000282172)
# Flux.mse(predict(x), y) = param(0.000282172)
# Flux.mse(predict(x), y) = param(0.000278365)
# Flux.mse(predict(x), y) = param(0.000278365)
# Flux.mse(predict(x), y) = param(0.000274605)
# Flux.mse(predict(x), y) = param(0.000274605)
# Flux.mse(predict(x), y) = param(0.000270894)
# Flux.mse(predict(x), y) = param(0.000270894)
# Flux.mse(predict(x), y) = param(0.000267231)
# Flux.mse(predict(x), y) = param(0.000267231)
# Flux.mse(predict(x), y) = param(0.000263615)
# Flux.mse(predict(x), y) = param(0.000263615)
# Flux.mse(predict(x), y) = param(0.000260044)
# Flux.mse(predict(x), y) = param(0.000260044)
# Flux.mse(predict(x), y) = param(0.00025652)
# Flux.mse(predict(x), y) = param(0.00025652)
# Flux.mse(predict(x), y) = param(0.000253041)
# Flux.mse(predict(x), y) = param(0.000253041)
# Flux.mse(predict(x), y) = param(0.000249607)
# Flux.mse(predict(x), y) = param(0.000249607)
# Flux.mse(predict(x), y) = param(0.000246217)
# Flux.mse(predict(x), y) = param(0.000246217)
# Flux.mse(predict(x), y) = param(0.000242871)
# Flux.mse(predict(x), y) = param(0.000242871)
# Flux.mse(predict(x), y) = param(0.000239568)
# Flux.mse(predict(x), y) = param(0.000239568)
# Flux.mse(predict(x), y) = param(0.000236307)
# Flux.mse(predict(x), y) = param(0.000236307)
# Flux.mse(predict(x), y) = param(0.000233089)
# Flux.mse(predict(x), y) = param(0.000233089)
# Flux.mse(predict(x), y) = param(0.000229912)
# Flux.mse(predict(x), y) = param(0.000229912)
# Flux.mse(predict(x), y) = param(0.000226776)
# Flux.mse(predict(x), y) = param(0.000226776)
# Flux.mse(predict(x), y) = param(0.000223681)
# Flux.mse(predict(x), y) = param(0.000223681)
# Flux.mse(predict(x), y) = param(0.000220626)
# Flux.mse(predict(x), y) = param(0.000220626)
# Flux.mse(predict(x), y) = param(0.000217611)
# Flux.mse(predict(x), y) = param(0.000217611)
# Flux.mse(predict(x), y) = param(0.000214634)
# Flux.mse(predict(x), y) = param(0.000214634)
# Flux.mse(predict(x), y) = param(0.000211696)
# Flux.mse(predict(x), y) = param(0.000211696)
# Flux.mse(predict(x), y) = param(0.000208797)
# Flux.mse(predict(x), y) = param(0.000208797)
# Flux.mse(predict(x), y) = param(0.000205935)
# Flux.mse(predict(x), y) = param(0.000205935)
# Flux.mse(predict(x), y) = param(0.00020311)
# Flux.mse(predict(x), y) = param(0.00020311)
# Flux.mse(predict(x), y) = param(0.000200322)
# Flux.mse(predict(x), y) = param(0.000200322)
# Flux.mse(predict(x), y) = param(0.000197571)
# Flux.mse(predict(x), y) = param(0.000197571)
# Flux.mse(predict(x), y) = param(0.000194855)
# Flux.mse(predict(x), y) = param(0.000194855)
# Flux.mse(predict(x), y) = param(0.000192175)
# Flux.mse(predict(x), y) = param(0.000192175)
# Flux.mse(predict(x), y) = param(0.000189529)
# Flux.mse(predict(x), y) = param(0.000189529)
# Flux.mse(predict(x), y) = param(0.000186919)
# Flux.mse(predict(x), y) = param(0.000186919)
# Flux.mse(predict(x), y) = param(0.000184342)
# Flux.mse(predict(x), y) = param(0.000184342)
# Flux.mse(predict(x), y) = param(0.000181799)
# Flux.mse(predict(x), y) = param(0.000181799)
# Flux.mse(predict(x), y) = param(0.00017929)
# Flux.mse(predict(x), y) = param(0.00017929)
# Flux.mse(predict(x), y) = param(0.000176813)
# Flux.mse(predict(x), y) = param(0.000176813)
# Flux.mse(predict(x), y) = param(0.000174369)
# Flux.mse(predict(x), y) = param(0.000174369)
# Flux.mse(predict(x), y) = param(0.000171957)
# Flux.mse(predict(x), y) = param(0.000171957)
# Flux.mse(predict(x), y) = param(0.000169577)
# Flux.mse(predict(x), y) = param(0.000169577)
# Flux.mse(predict(x), y) = param(0.000167227)
# Flux.mse(predict(x), y) = param(0.000167227)
# Flux.mse(predict(x), y) = param(0.000164909)
# Flux.mse(predict(x), y) = param(0.000164909)
# Flux.mse(predict(x), y) = param(0.000162622)
# Flux.mse(predict(x), y) = param(0.000162622)
# Flux.mse(predict(x), y) = param(0.000160364)
# Flux.mse(predict(x), y) = param(0.000160364)
# Flux.mse(predict(x), y) = param(0.000158136)
# Flux.mse(predict(x), y) = param(0.000158136)
# Flux.mse(predict(x), y) = param(0.000155938)
# Flux.mse(predict(x), y) = param(0.000155938)
# Flux.mse(predict(x), y) = param(0.000153769)
# Flux.mse(predict(x), y) = param(0.000153769)
# Flux.mse(predict(x), y) = param(0.000151628)
# Flux.mse(predict(x), y) = param(0.000151628)
# Flux.mse(predict(x), y) = param(0.000149515)
# Flux.mse(predict(x), y) = param(0.000149515)
# Flux.mse(predict(x), y) = param(0.000147431)
# Flux.mse(predict(x), y) = param(0.000147431)
# Flux.mse(predict(x), y) = param(0.000145374)
# Flux.mse(predict(x), y) = param(0.000145374)
# Flux.mse(predict(x), y) = param(0.000143345)
# Flux.mse(predict(x), y) = param(0.000143345)
# Flux.mse(predict(x), y) = param(0.000141342)
# Flux.mse(predict(x), y) = param(0.000141342)
# Flux.mse(predict(x), y) = param(0.000139366)
# Flux.mse(predict(x), y) = param(0.000139366)
# Flux.mse(predict(x), y) = param(0.000137416)
# Flux.mse(predict(x), y) = param(0.000137416)
# Flux.mse(predict(x), y) = param(0.000135492)
# Flux.mse(predict(x), y) = param(0.000135492)
# Flux.mse(predict(x), y) = param(0.000133594)
# Flux.mse(predict(x), y) = param(0.000133594)
# Flux.mse(predict(x), y) = param(0.000131721)
# Flux.mse(predict(x), y) = param(0.000131721)
# Flux.mse(predict(x), y) = param(0.000129873)
# Flux.mse(predict(x), y) = param(0.000129873)
# Flux.mse(predict(x), y) = param(0.00012805)
# Flux.mse(predict(x), y) = param(0.00012805)
# Flux.mse(predict(x), y) = param(0.000126251)
# Flux.mse(predict(x), y) = param(0.000126251)
# Flux.mse(predict(x), y) = param(0.000124476)
# Flux.mse(predict(x), y) = param(0.000124476)
# Flux.mse(predict(x), y) = param(0.000122724)
# Flux.mse(predict(x), y) = param(0.000122724)
# Flux.mse(predict(x), y) = param(0.000120996)
# Flux.mse(predict(x), y) = param(0.000120996)
# Flux.mse(predict(x), y) = param(0.000119292)
# Flux.mse(predict(x), y) = param(0.000119292)
# Flux.mse(predict(x), y) = param(0.00011761)
# Flux.mse(predict(x), y) = param(0.00011761)
# Flux.mse(predict(x), y) = param(0.00011595)
# Flux.mse(predict(x), y) = param(0.00011595)
# Flux.mse(predict(x), y) = param(0.000114313)
# Flux.mse(predict(x), y) = param(0.000114313)
# Flux.mse(predict(x), y) = param(0.000112698)
# Flux.mse(predict(x), y) = param(0.000112698)
# Flux.mse(predict(x), y) = param(0.000111105)
# Flux.mse(predict(x), y) = param(0.000111105)
# Flux.mse(predict(x), y) = param(0.000109533)
# Flux.mse(predict(x), y) = param(0.000109533)
# Flux.mse(predict(x), y) = param(0.000107982)
# Flux.mse(predict(x), y) = param(0.000107982)
# Flux.mse(predict(x), y) = param(0.000106452)
# Flux.mse(predict(x), y) = param(0.000106452)
# Flux.mse(predict(x), y) = param(0.000104942)
# Flux.mse(predict(x), y) = param(0.000104942)
# Flux.mse(predict(x), y) = param(0.000103453)
# Flux.mse(predict(x), y) = param(0.000103453)
# Flux.mse(predict(x), y) = param(0.000101984)
# Flux.mse(predict(x), y) = param(0.000101984)
# Flux.mse(predict(x), y) = param(0.000100535)
# Flux.mse(predict(x), y) = param(0.000100535)
# Flux.mse(predict(x), y) = param(9.91059e-5)

# %%
loss(x, y)
# Out:
# Flux.mse(predict(x), y) = param(9.91059e-5)
# Tracked 0-dimensional Array{Float64,0}:
# 9.91059e-5

# %%
w₀
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# -0.118862

# %%
w
# Out:
# Tracked 10-element Array{Float64,1}:
#  -0.00837842
#  -0.0421885
#  -0.346986
#   0.133717
#   0.210968
#   0.951916
#   0.999905
#   0.251662
#   0.986666
#   0.555751

# %%
v
# Out:
# Tracked 10×4 Array{Float64,2}:
#   0.170218    0.363741    -0.0876893    0.614795
#   0.157321    0.608635    -0.168786     0.366462
#   0.534607   -0.00926567   0.761433     0.128015
#   0.0135002   0.47331     -0.218409    -0.141018
#  -0.0637745   0.369079     0.272776     0.339354
#  -0.0156902  -0.201246     0.187501     0.588058
#  -0.252925    0.573547     0.00866154   0.240333
#   0.0148486  -0.204198    -0.0997698   -0.0499051
#   0.610656    0.275517     0.284677     0.608333
#  -0.201888    0.183321     0.100217     0.154108

# %%
x
# Out:
# 10-element Array{Float64,1}:
#  0.404673
#  0.736787
#  0.953803
#  0.0951856
#  0.519675
#  0.0135403
#  0.303399
#  0.702557
#  0.596537
#  0.638935

# %%
rand(10) ./ 10
# Out:
# 10-element Array{Float64,1}:
#  0.0548635
#  0.0262992
#  0.0526443
#  0.0465019
#  0.0275519
#  0.0461823
#  0.0951861
#  0.0288737
#  0.0661232
#  0.0194568

# %%
predict(x .+ (rand(10) ./ 10))
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# 1.22821

# %%
predict(x)
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# 0.882303

# %%
y
# Out:
# 0.8723474485143243
